# %%
import pandas as pd

# %%
bike_trip = pd.read_csv('cleandata/201512citibiketrips.csv')
bike_trip.head()
# Out:
#   end station name  trips
# 0  1 Ave & E 15 St   4162
# 1  1 Ave & E 18 St   2767
# 2  1 Ave & E 30 St   3162
# 3  1 Ave & E 44 St   1829
# 4  1 Ave & E 62 St   1955

# %%
data2019 = pd.read_csv('cleandata/201912customerdata.csv')
data2020 = pd.read_csv('cleandata/202012customerdata.csv')

# %%
data2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 1           404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 2          1223  2019-12-01 00:00:39.7930  2019-12-01 00:21:03.6680
# 3          1570  2019-12-01 00:01:57.0540  2019-12-01 00:28:07.7410
# 4           633  2019-12-01 00:02:14.8210  2019-12-01 00:12:48.0130
#
#    start station id      start station name  start station latitude  \
# 0               362      Broadway & W 37 St               40.751726
# 1              3834  Irving Ave & Halsey St               40.694670
# 2               465      Broadway & W 41 St               40.755136
# 3               309     Murray St & West St               40.714979
# 4              3134         3 Ave & E 62 St               40.763126
#
#    start station longitude  end station id      end station name  \
# 0               -73.987535             500    Broadway & W 51 St
# ...

# %%
data2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           694  2020-12-01 00:00:03.7770  2020-12-01 00:11:38.3160
# 1          2182  2020-12-01 00:00:36.4030  2020-12-01 00:36:59.0330
# 2           525  2020-12-01 00:02:10.3850  2020-12-01 00:10:55.5480
# 3           331  2020-12-01 00:02:20.3350  2020-12-01 00:07:51.4080
# 4          1396  2020-12-01 00:03:15.3130  2020-12-01 00:26:32.3010
#
#    start station id           start station name  start station latitude  \
# 0              4065     Wadsworth Ave & W 179 St               40.848467
# 1              3165  Central Park West & W 72 St               40.775794
# 2              3338              2 Ave & E 99 St               40.786259
# 3              3443              W 52 St & 6 Ave               40.761330
# 4              4106         Ogden Ave & W 164 St               40.832812
#
#    start station longitude  end station id          end station name  \
# ...

# %%
tables = [data2019,data2020]
combined_customer = pd.concat(tables)
combined_customer
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 1               404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 2              1223  2019-12-01 00:00:39.7930  2019-12-01 00:21:03.6680
# 3              1570  2019-12-01 00:01:57.0540  2019-12-01 00:28:07.7410
# 4               633  2019-12-01 00:02:14.8210  2019-12-01 00:12:48.0130
# ...             ...                       ...                       ...
# 91892           128  2020-12-31 23:50:12.8700  2020-12-31 23:52:21.6490
# 91893           166  2020-12-31 23:52:24.0550  2020-12-31 23:55:10.5220
# 91894          4727  2020-12-31 23:55:41.0840  2021-01-01 01:14:28.5180
# 91895           268  2020-12-31 23:56:35.5290  2021-01-01 00:01:03.8460
# 91896          1178  2020-12-31 23:58:14.1000  2021-01-01 00:17:52.3380
#
#        start station id         start station name  start station latitude  \
# ...

# %%
combined_customer.to_csv('cleandata/customer2020_2019.csv', index = False)
